# %% [markdown]
# # Section A Theory Ouestion

# %% [markdown]
# Question 1. What is Object-Oriented Programming (OOP)?
#
# Answer: Object-Oriented Programming (OOP) is a programming paradigm that organizes code using objects and classes. It focuses on concepts like encapsulation, inheritance, polymorphism, and abstraction to make programs modular, reusable, and easier to maintain.

# %% [markdown]
# Question 2. What is a class in OOP?
#
# Answer: A class is a blueprint or template used to create objects. It defines attributes (variables) and methods (functions).

# %% [markdown]
# Question 3. What is an object in OOP?
#
# Answer 3: An object is an instance of a class. It represents a real-world entity.

# %% [markdown]
# Question 4. Difference between abstraction and encapsulation
# Abstraction	Encapsulation
#
# Answer : Hides implementation details	Hides data using private variables
# Focuses on what to show	Focuses on data protection
# Achieved using abstract classes	Achieved using private variables
#
#
# Question 5. What are dunder methods in Python?
#
# Answer : Dunder methods (double underscore methods) are special methods like:
#
# __init__, __str__, __add__, __len__
#
#
# They define special behavior of objects.

# %% [markdown]
# Question 6. Explain inheritance in OOP
#
# Answer : Inheritance allows a class to inherit properties and methods from another class.
#
# Question 7. What is polymorphism in OOP?
#
# Answer : Polymorphism means same method name, different behavior.
#
# Example:
#
# Question 8. How is encapsulation achieved in Python?
#
# Answer : Encapsulation is achieved using private variables with double underscore.
#
# Example:
#
#
# Question 9. What is a constructor in Python?
#
# Answer : A constructor initializes object data automatically when object is created.
#
# Example:
#
# Question 10. What are class and static methods?
#
# Answer : Class Method
#
# A class method is a method that is bound to the class, not the object.
# It takes cls (class reference) as its first parameter.
#
# Defined using @classmethod decorator
#
# Can access and modify class variables
#
# Cannot directly access instance variables
#
# Example:
#
#
# Ques 11. What is method overloading?
#
# Answer : Method overloading means same method name with different parameters.
#
# Python achieves it using default arguments.
#
# Ques.12. What is method overriding?
#
# Answer : When child class provides its own implementation of parent method
#
# Question 13. What is property decorator?
#
# Answer : It allows method to be used like attribute.
#
# Example:
#
# Ques.14. Why is polymorphism important?
#
# Answer : Benefits:
#
# - Code reuse
#
# - Flexibility
#
# - Easy maintenance
#
# - Cleaner code
#
# Ques.15. What is abstract class in Python?
#
# Answer : Abstract class cannot be instantiated and contains abstract methods.
#
# Example:
#
# from abc import ABC, abstractmethod
#
#
# Ques.16. Advantages of OOP
#
# Answer :
# • Code reuse
# • Easy maintenance
# • Better organization
# • Security
# • Scalability
#
# Ques.17. Difference between class variable and instance variable
#
# Answer : Class variable: A variable that is shared among all objects of a class.
#
# Instance variable: A variable that is unique to each object and defined inside the constructor.
#
# So
#
# Ques.18. What is multiple inheritance?
#
# Answer : When class inherits from more than one class.
#
# Example:
#
# class A: pass
# class B: pass
# class C(A, B): pass
#
# Ques.19. Purpose of str and repr
#
# Answer : Both __str__ and __repr__ are special (dunder) methods used to define how an object is displayed.
#
# 1 __str__ Method
#
# Used to return a user-friendly (readable) string representation of an object
#
# Called when using print() or str()
#
# Example:
#
# Quest.20 Significance of super()
#
# Answer : super() calls parent class methods.
#
# Example:
#
# super().__init__()

# %% [markdown]
# Ques.21. Significance of del method?
#
# Ans:The __del__ method is a destructor that is automatically called when an object is destroyed. It is used to perform cleanup tasks like releasing resources or memory.
#
#  Explanation:
#
# __init__ → called when object is created
#
# __del__ → called when object is deleted or destroyed

# %% [markdown]
# Ques. 22  Difference between @staticmethod and @classmethod
# staticmethod	classmethod?
#
# Ans : @staticmethod is a method that does not use class or instance variables, while @classmethod is a method that uses the class (cls) and can access or modify class variables.

# %% [markdown]
# Ques.23 How polymorphism works with inheritance
#
# Answer : Polymorphism in inheritance works when child classes override the parent class method and provide their own implementation. The same method name behaves differently depending on the object, which is called runtime polymorphism.

# %% [markdown]
# Ques.24 What is method chaining?
#
# Ans: Method chaining is a technique in which multiple methods are called on the same object in a single line, one after another.
#
# It works by returning the object itself (self) from each method, so the next method can be called.

# %% [markdown]
# Ques.25. Purpose of call method
#
# Ans. The __call__ method allows an object to be called like a function using parentheses. When an object is called, Python automatically executes its __call__ method.

# %% [markdown]
# # Section B Practical Question

# %% [markdown]
# Question 1.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Test
a = Animal()
d = Dog()

a.speak()
d.speak()
# Out:
# Animal makes a sound
# Bark!

# %% [markdown]
# Question 2:

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


c = Circle(5)
r = Rectangle(4, 6)

print("Circle area:", c.area())
print("Rectangle area:", r.area())
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %% [markdown]
# Ques.3:

# %%
class Vehicle:

    def __init__(self, type):
        self.type = type

class Car(Vehicle):

    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):

    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

e = ElectricCar("Car", "Tesla", "75kWh")

print(e.type)
print(e.brand)
print(e.battery)
# Out:
# Car
# Tesla
# 75kWh

# %% [markdown]
# Ques.4

# %%
class Bird:

    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):

    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):

    def fly(self):
        print("Penguin cannot fly")

b = Bird()
s = Sparrow()
p = Penguin()

b.fly()
s.fly()
p.fly()
# Out:
# Bird can fly
# Sparrow flies high
# Penguin cannot fly

# %% [markdown]
# Ques.5

# %%
class BankAccount:

    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        print("Balance:", self.__balance)


acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(200)
acc.check_balance()
# Out:
# Balance: 1300

# %% [markdown]
# Ques.6

# %%
class Instrument:

    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):

    def play(self):
        print("Guitar is playing")

class Piano(Instrument):

    def play(self):
        print("Piano is playing")

i = Instrument()
g = Guitar()
p = Piano()

i.play()
g.play()
p.play()
# Out:
# Instrument is playing
# Guitar is playing
# Piano is playing

# %% [markdown]
# Ques.7

# %%
class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


print(MathOperations.add_numbers(10, 5))
print(MathOperations.subtract_numbers(10, 5))
# Out:
# 15
# 5

# %% [markdown]
# Ques.8

# %%
class Person:

    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count


p1 = Person("A")
p2 = Person("B")

print("Total persons:", Person.total_persons())
# Out:
# Total persons: 2

# %% [markdown]
# Ques.9

# %%
class Fraction:

    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %% [markdown]
# Ques.10

# %%
class Vector:

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2

print(v3)
# Out:
# (6, 8)

# %% [markdown]
# Ques.11

# %%
class Person:

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


p = Person("Rahul", 20)
p.greet()
# Out:
# Hello, my name is Rahul and I am 20 years old.

# %% [markdown]
# Ques.12

# %%
class Student:

    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


s = Student("Aman", [80, 90, 85])

print("Average:", s.average_grade())
# Out:
# Average: 85.0

# %% [markdown]
# Ques.13

# %%
class Rectangle:

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle()
r.set_dimensions(5, 6)

print("Area:", r.area())
# Out:
# Area: 30

# %% [markdown]
# Ques.14

# %%
class Employee:

    def __init__(self, hours, rate):
        self.hours = hours
        self.rate = rate

    def calculate_salary(self):
        return self.hours * self.rate

class Manager(Employee):

    def __init__(self, hours, rate, bonus):
        super().__init__(hours, rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus


m = Manager(40, 50, 1000)

print("Salary:", m.calculate_salary())
# Out:
# Salary: 3000

# %% [markdown]
# Ques.15

# %%
class Product:

    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


p = Product("Pen", 10, 5)

print("Total price:", p.total_price())
# Out:
# Total price: 50

# %% [markdown]
# Ques.16

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):

    def sound(self):
        print("Moo")

class Sheep(Animal):

    def sound(self):
        print("Baa")

c = Cow()
s = Sheep()

c.sound()
s.sound()
# Out:
# Moo
# Baa

# %% [markdown]
# Ques.17

# %%
class Book:

    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, published in {self.year}"


b = Book("Python", "John", 2023)

print(b.get_book_info())
# Out:
# Python by John, published in 2023

# %% [markdown]
# Ques.18

# %%
class House:

    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):

    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


m = Mansion("Delhi", 5000000, 10)

print(m.address)
print(m.price)
print(m.number_of_rooms)
# Out:
# Delhi
# 5000000
# 10
